# %% [markdown]
# # An analysis of sleep in ten volunteers

# %% [markdown]
# ## Abstract
#
# Ten volunteers slept eight hours a night for a week. Sleep quality rose over the week.

# %% [markdown]
# ## Introduction
#
# Sleep quality varies from night to night [1].

# %% [markdown]
# ## Methods
#
# Volunteers wore a wrist monitor for 7 nights. We analyzed the traces in Python.

# %%
import numpy as np
x = np.zeros(10)

# %% [markdown]
# ## Results
#
# Sleep quality rose by 12% over the week (Fig. 1).

# %% [markdown]
# ## Discussion
#
# Sleep quality rose over the week. One limitation is the sample of ten.

# %% [markdown]
# ## References
#
# 1. Doe A. A paper. Sleep. 2019;1:1–2.
