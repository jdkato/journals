# %% [markdown]
# # A Novel Analysis Of Sleep Data

# %% [markdown]
# ## Abstract
#
# The data was very noisy [1]. 10 subjects slept 8hrs.

# %% [markdown]
# ## Introduction
#
# Sleep is important. See the figure below.

# %%
import numpy as np
x = np.zeros(10)  # TODO real data

# %% [markdown]
# ## Results
#
# The effect was significant. TODO: add Figure 1, then see Fig. 2.

# %% [markdown]
# ## Discussion
#
# This proves sleep matters. It may possibly generalize.
